# %% [markdown]
# Code for **"Prior effect"** figure from supmat.

# %% [markdown]
# # Import libs

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline

import argparse
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '1'

import numpy as np
from models import *

import torch
import torch.optim

from skimage.measure import compare_psnr
from models.downsampler import Downsampler

from utils.sr_utils import *

torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark =True
# dtype = torch.cuda.FloatTensor
dtype = torch.FloatTensor

imsize =-1 
factor = 4
enforse_div32 = 'CROP' # we usually need the dimensions to be divisible by a power of two

PLOT = True

# %% [markdown]
# # Load image

# %%
fname  = 'data/sr/zebra_crop.png'

imgs = load_LR_HR_imgs_sr(fname, imsize, factor, enforse_div32)

if PLOT:
    imgs['bicubic_np'], imgs['sharp_np'], imgs['nearest_np'] = get_baselines(imgs['LR_pil'], imgs['HR_pil'])
    plot_image_grid([imgs['HR_np'], imgs['bicubic_np'], imgs['sharp_np'], imgs['nearest_np']], 4,12);
    print ('PSNR bicubic: %.4f   PSNR nearest: %.4f' %  (
                                        compare_psnr(imgs['HR_np'], imgs['bicubic_np']), 
                                        compare_psnr(imgs['HR_np'], imgs['nearest_np'])))
# Out:
# HR and LR resolutions: (256, 160), (64, 40)
# PSNR bicubic: 20.6285   PSNR nearest: 17.4030

# %%
def closure():
    
    global i
    
    if reg_noise_std > 0:
        net_input.data = net_input_saved + (noise.normal_() * reg_noise_std)
        
    out_HR = net(net_input)
    out_LR = downsampler(out_HR)

    total_loss = mse(out_LR, img_LR_var) + tv_weight * tv_loss(out_HR)
    total_loss.backward()

    # Log
    psnr_LR = compare_psnr(imgs['LR_np'], var_to_np(out_LR))
    psnr_HR = compare_psnr(imgs['HR_np'], var_to_np(out_HR))
    print ('Iteration %05d    PSNR_LR %.3f   PSNR_HR %.3f' % (i, psnr_LR, psnr_HR), '\r', end='')
                      
    # History
    psnr_history.append([psnr_LR, psnr_HR])
    
    if PLOT and i % 500 == 0:
        out_HR_np = var_to_np(out_HR)
        plot_image_grid([imgs['HR_np'], np.clip(out_HR_np, 0, 1)], factor=8, nrow=2, interpolation='lanczos')

    i += 1
    
    return total_loss

# %% [markdown]
# # Experiment 1: no prior, optimize over pixels

# %%
input_depth = 3
 
INPUT = 'noise'
pad = 'reflection'
OPT_OVER = 'input'
KERNEL_TYPE='lanczos2'

LR = 0.01
tv_weight = 0.0

OPTIMIZER = 'adam'

num_iter = 2000
reg_noise_std = 0.0

# %%
# Identity mapping network, optimize over `net_input`
net = nn.Sequential()
net_input = get_noise(input_depth, INPUT, (imgs['HR_pil'].size[1], imgs['HR_pil'].size[0])).type(dtype).detach()

downsampler = Downsampler(n_planes=3, factor=factor, kernel_type='lanczos2', phase=0.5, preserve_size=True).type(dtype)

# Loss
mse = torch.nn.MSELoss().type(dtype)

img_LR_var = np_to_var(imgs['LR_np']).type(dtype)

# %%
psnr_history = [] 
i = 0
 
p = get_params(OPT_OVER, net, net_input)
optimize(OPTIMIZER, p, closure, LR, num_iter)
# Out:
# Starting optimization with ADAM
# Iteration 00000    PSNR_LR 7.278   PSNR_HR 7.034
# Iteration 00500    PSNR_LR 121.523   PSNR_HR 14.192
# Iteration 01000    PSNR_LR 139.442   PSNR_HR 14.192
# Iteration 01500    PSNR_LR 142.988   PSNR_HR 14.192
# Iteration 01675    PSNR_LR 143.997   PSNR_HR 14.192
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-eb9f2f270b4b> in <module>()
#       3
#       4 p = get_params(OPT_OVER, net, net_input)
# ----> 5 optimize(OPTIMIZER, p, closure, LR, num_iter)
#
# ~/Development/tmp/deep-image-prior/utils/common_utils.py in optimize(optimizer_type, parameters, closure, LR, num_iter, downsampler)
#     227         for j in range(num_iter):
#     228             optimizer.zero_grad()
# --> 229             closure()
#     230             optimizer.step()
#     231     else:
#
# <ipython-input-9-689fcf047703> in closure()
#       9     out_LR = downsampler(out_HR)
#      10
# ---> 11     total_loss = mse(out_LR, img_LR_var) + tv_weight * tv_loss(out_HR)
#      12     total_loss.backward()
#      13
#
# ~/Development/tmp/deep-image-prior/utils/sr_utils.py in tv_loss(x, beta)
#      83     dw = torch.pow(x[:,:,1:,:] - x[:,:,:-1,:], 2)
#      84
# ---> 85     return torch.sum(torch.pow(dh[:, :, :-1] + dw[:, :, :, :-1], beta))
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/autograd/variable.py in pow(self, other)
#     364         else:
#     365             assert not torch.is_tensor(other)
# --> 366             return PowConstant.apply(self, other)
#     367
#     368     def exp(self):
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/autograd/_functions/basic_ops.py in forward(ctx, a, b)
#     198         if ctx.tensor_first:
#     199             ctx.save_for_backward(tensor)
# --> 200             return tensor.pow(ctx.constant)
#     201         else:
#     202             result = torch.pow(ctx.constant, tensor)
#
# KeyboardInterrupt:

# %%
out_HR_np = np.clip(var_to_np(net(net_input)), 0, 1)

result_no_prior = put_in_center(out_HR_np, imgs['orig_np'].shape[1:])
psnr_history_direct = psnr_history
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bf3f80cf5744> in <module>()
#       1 out_HR_np = np.clip(var_to_np(net(net_input)), 0, 1)
#       2
# ----> 3 result_no_prior = put_in_center(out_HR_np, imgs['orig_np'].shape[1:])
#       4 psnr_history_direct = psnr_history
#
# ~/Development/tmp/deep-image-prior/utils/sr_utils.py in put_in_center(img_np, target_size)
#      11     ]
#      12
# ---> 13     img_out[:, bbox[0]:bbox[2], bbox[1]:bbox[3]] = img_np
#      14
#      15     return img_out
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# # Experiment 2: using TV loss

# %%
tv_weight = 1e-7
net_input = get_noise(input_depth, INPUT, (imgs['HR_pil'].size[1], imgs['HR_pil'].size[0])).type(dtype).detach()

psnr_history = [] 
i = 0
 
p = get_params(OPT_OVER, net, net_input)
optimize(OPTIMIZER, p, closure, LR, num_iter)
# Out:
# Starting optimization with ADAM
# Iteration 00000    PSNR_LR 7.272   PSNR_HR 7.028
# Iteration 00500    PSNR_LR 48.433   PSNR_HR 20.555
# Iteration 01000    PSNR_LR 49.341   PSNR_HR 22.089
# Iteration 01500    PSNR_LR 49.529   PSNR_HR 22.473
# Iteration 01999    PSNR_LR 49.576   PSNR_HR 22.594

# %%
out_HR_np = np.clip(var_to_np(net(net_input)), 0, 1)

result_tv_prior = put_in_center(out_HR_np, imgs['orig_np'].shape[1:])
psnr_history_tv = psnr_history
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c841a0ec8e32> in <module>()
#       1 out_HR_np = np.clip(var_to_np(net(net_input)), 0, 1)
#       2
# ----> 3 result_tv_prior = put_in_center(out_HR_np, imgs['orig_np'].shape[1:])
#       4 psnr_history_tv = psnr_history
#
# ~/Development/tmp/deep-image-prior/utils/sr_utils.py in put_in_center(img_np, target_size)
#      11     ]
#      12
# ---> 13     img_out[:, bbox[0]:bbox[2], bbox[1]:bbox[3]] = img_np
#      14
#      15     return img_out
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# # Experiment 3: using deep prior

# %% [markdown]
# Same setting, but use parametrization.

# %%
OPT_OVER = 'net'
reg_noise_std = 1./30. # This parameter probably should be set to a lower value for this example
tv_weight = 0.0

net = skip(input_depth, 3, num_channels_down = [128, 128, 128, 128, 128], 
                           num_channels_up   = [128, 128, 128, 128, 128],
                           num_channels_skip = [4, 4, 4, 4, 4], 
                           upsample_mode='bilinear',
                           need_sigmoid=True, need_bias=True, pad=pad, act_fun='LeakyReLU').type(dtype)

net_input = get_noise(input_depth, INPUT, (imgs['HR_pil'].size[1], imgs['HR_pil'].size[0])).type(dtype).detach()

# Compute number of parameters
s  = sum([np.prod(list(p.size())) for p in net.parameters()]); 
print ('Number of params: %d' % s)
# Out:
# Number of params: 2184307

# %%
psnr_history = [] 
net_input_saved = net_input.data.clone()
noise = net_input.data.clone()

i = 0
p = get_params(OPT_OVER, net, net_input)
optimize(OPTIMIZER, p, closure, LR, num_iter)
# Out:
# Starting optimization with ADAM
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-24b501e759a2> in <module>()
#       5 i = 0
#       6 p = get_params(OPT_OVER, net, net_input)
# ----> 7 optimize(OPTIMIZER, p, closure, LR, num_iter)
#
# ~/Development/tmp/deep-image-prior/utils/common_utils.py in optimize(optimizer_type, parameters, closure, LR, num_iter, downsampler)
#     227         for j in range(num_iter):
#     228             optimizer.zero_grad()
# --> 229             closure()
#     230             optimizer.step()
#     231     else:
#
# <ipython-input-9-689fcf047703> in closure()
#       6         net_input.data = net_input_saved + (noise.normal_() * reg_noise_std)
#       7
# ----> 8     out_HR = net(net_input)
#       9     out_LR = downsampler(out_HR)
#      10
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/Development/tmp/deep-image-prior/models/common.py in forward(self, input)
#      19         inputs = []
#      20         for module in self._modules.values():
# ---> 21             inputs.append(module(input))
#      22
#      23         return torch.cat(inputs, dim=self.dim)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/modules/padding.py in forward(self, input)
#      35
#      36     def forward(self, input):
# ---> 37         return F.pad(input, self.padding, 'reflect')
#      38
#      39     def __repr__(self):
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/functional.py in pad(input, pad, mode, value)
#    1031             return ConstantPad2d.apply(input, pad, value)
#    1032         elif mode == 'reflect':
# -> 1033             return _functions.thnn.ReflectionPad2d.apply(input, *pad)
#    1034         elif mode == 'replicate':
#    1035             return _functions.thnn.ReplicationPad2d.apply(input, *pad)
#
# ~/miniconda3/envs/tensorflow_1_3/lib/python3.6/site-packages/torch/nn/_functions/thnn/auto.py in forward(ctx, input, *params)
#     172             del ctx.buffers
#     173
# --> 174         getattr(ctx._backend, update_output.name)(ctx._backend.library_state, input, output, *args)
#     175         return output
#     176
#
# TypeError: FloatSpatialReflectionPadding_updateOutput received an invalid combination of arguments - got (int, torch.FloatTensor, torch.FloatTensor, float, float, float, float), but expected (int state, torch.FloatTensor input, torch.FloatTensor output, int pad_l, int pad_r, int pad_t, int pad_b)

# %%
out_HR_np = np.clip(var_to_np(net(net_input)), 0, 1)

result_deep_prior = put_in_center(out_HR_np, imgs['orig_np'].shape[1:])
psnr_history_deep_prior = psnr_history

# %% [markdown]
# # Comparison

# %%
plot_image_grid([imgs['HR_np'], 
                 result_no_prior, 
                 result_tv_prior, 
                 result_deep_prior], factor=8, nrow=2, interpolation='lanczos');
